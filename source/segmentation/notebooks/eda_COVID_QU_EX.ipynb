# %%
# link Train dataset: https://www.kaggle.com/datasets/cf77495622971312010dd5934ee91f07ccbcfdea8e2f7778977ea8485c1914df

# %%
# import module
# import sys
# sys.path.insert(0, '/mnt/DATA/research/project/classificationCOVID19applyseg/source/segmentation/')

# from dataloader.transform import augs, img_de_normalize
# from visualize import imshow_img_mask, visualize_distribute_dataset
# from custom_dataset import ImageDataset
# from utils import transfms_M_STD, compute_mean_std

# import lib
import pandas as pd
import albumentations  as A
from albumentations.pytorch.transforms import ToTensorV2
import matplotlib.pyplot as plt
import os
from torch.utils.data import DataLoader
import torch
from tqdm import tqdm

# %%
# data_dir = './COVID_QU_Ex_dataset'
lung_data = '/mnt/DATA/covid19_resnet152_python-main/archive_14gb/COVID_QU_Ex/Lung Segmentation Data/Lung Segmentation Data/'

# %%
# tao dict với key = file_name, value = label
label = os.listdir(lung_data+'Train')
dict_img = {}
for lbl in label:
    for file_name in os.listdir(lung_data+'Train/' +lbl +'/images'):
        dict_img[file_name]=lbl
dict_img
# Out:
# {'non_COVID (2869).png': 'Non-COVID',
#  'non_COVID (8492).png': 'Non-COVID',
#  'non_COVID (8910).png': 'Non-COVID',
#  'non_COVID (2237).png': 'Non-COVID',
#  'non_COVID (1866).png': 'Non-COVID',
#  'non_COVID (9852).png': 'Non-COVID',
#  'non_COVID (6186).png': 'Non-COVID',
#  'non_COVID (9581).png': 'Non-COVID',
#  'non_COVID (9082).png': 'Non-COVID',
#  'non_COVID (6514).png': 'Non-COVID',
#  'non_COVID (6247).png': 'Non-COVID',
#  'non_COVID (3085).png': 'Non-COVID',
#  'non_COVID (8358).png': 'Non-COVID',
#  'non_COVID (8060).png': 'Non-COVID',
#  'non_COVID (9796).png': 'Non-COVID',
#  'non_COVID (9095).png': 'Non-COVID',
#  'non_COVID (7116).png': 'Non-COVID',
#  'non_COVID (8510).png': 'Non-COVID',
#  'non_COVID (1147).png': 'Non-COVID',
#  'non_COVID (2762).png': 'Non-COVID',
#  'non_COVID (10537).png': 'Non-COVID',
#  'non_COVID (1105).png': 'Non-COVID',
#  'non_COVID (8882).png': 'Non-COVID',
#  'non_COVID (8706).png': 'Non-COVID',
#  'non_COVID (6775).png': 'Non-COVID',
#  'non_COVID (3214).png': 'Non-COVID',
#  'non_COVID (6630).png': 'Non-COVID',
#  'non_COVID (2440).png': 'Non-COVID',
#  'non_COVID (9046).png': 'Non-COVID',
#  'Non_COVID (73).png': 'Non-COVID',
#  'non_COVID (9031).png': 'Non-COVID',
#  'non_COVID (6177).png': 'Non-COVID',
#  'non_COVID (7623).png': 'Non-COVID',
#  'non_COVID (335).png': 'Non-COVID',
#  'non_COVID (8774).png': 'Non-COVID',
#  'non_COVID (7716).png': 'Non-COVID',
#  'non_COVID (6647).png': 'Non-COVID',
#  'non_COVID (7822).png': 'Non-COVID',
#  'non_COVID (259).png': 'Non-COVID',
#  'non_COVID (7879).png': 'Non-COVID',
#  'non_COVID (1026).png': 'Non-COVID',
#  'non_COVID (6327).png': 'Non-COVID',
#  'non_COVID (2891).png': 'Non-COVID',
#  'non_COVID (7399).png': 'Non-COVID',
#  'non_COVID (2859).png': 'Non-COVID',
#  'non_COVID (10038).png': 'Non-COVID',
#  'Non_COVID (75).png': 'Non-COVID',
#  'non_COVID (7476).png': 'Non-COVID',
#  'non_COVID (6339).png': 'Non-COVID',
#  'non_COVID (3208).png': 'Non-COVID',
#  'non_COVID (6541).png': 'Non-COVID',
#  'non_COVID (2359).png': 'Non-COVID',
#  'non_COVID (7854).png': 'Non-COVID',
#  'non_COVID (7598).png': 'Non-COVID',
#  'non_COVID (7230).png': 'Non-COVID',
#  'non_COVID (8444).png': 'Non-COVID',
#  'non_COVID (1399).png': 'Non-COVID',
#  'non_COVID (9906).png': 'Non-COVID',
#  'non_COVID (8822).png': 'Non-COVID',
#  'non_COVID (8309).png': 'Non-COVID',
#  'non_COVID (2133).png': 'Non-COVID',
#  'non_COVID (8815).png': 'Non-COVID',
#  'non_COVID (10027).png': 'Non-COVID',
#  'non_COVID (310).png': 'Non-COVID',
#  'non_COVID (9669).png': 'Non-COVID',
#  'non_COVID (8789).png': 'Non-COVID',
#  'non_COVID (1746).png': 'Non-COVID',
#  'non_COVID (811).png': 'Non-COVID',
#  'non_COVID (7613).png': 'Non-COVID',
#  'non_COVID (6926).png': 'Non-COVID',
#  'non_COVID (2864).png': 'Non-COVID',
#  'non_COVID (9476).png': 'Non-COVID',
#  'non_COVID (770).png': 'Non-COVID',
#  'non_COVID (7773).png': 'Non-COVID',
#  'non_COVID (2406).png': 'Non-COVID',
#  'non_COVID (9980).png': 'Non-COVID',
#  'non_COVID (9409).png': 'Non-COVID',
#  'non_COVID (8681).png': 'Non-COVID',
#  'non_COVID (10207).png': 'Non-COVID',
#  'non_COVID (8561).png': 'Non-COVID',
#  'non_COVID (6241).png': 'Non-COVID',
#  'non_COVID (7335).png': 'Non-COVID',
#  'non_COVID (6908).png': 'Non-COVID',
#  'non_COVID (8044).png': 'Non-COVID',
#  'non_COVID (2658).png': 'Non-COVID',
#  'non_COVID (7108).png': 'Non-COVID',
#  'non_COVID (605).png': 'Non-COVID',
#  'non_COVID (9382).png': 'Non-COVID',
#  'non_COVID (9380).png': 'Non-COVID',
#  'non_COVID (9625).png': 'Non-COVID',
#  'non_COVID (1196).png': 'Non-COVID',
#  'non_COVID (6941).png': 'Non-COVID',
#  'non_COVID (9688).png': 'Non-COVID',
#  'non_COVID (7862).png': 'Non-COVID',
#  'non_COVID (162).png': 'Non-COVID',
#  'non_COVID (8566).png': 'Non-COVID',
#  'non_COVID (662).png': 'Non-COVID',
#  'non_COVID (9510).png': 'Non-COVID',
#  'non_COVID (8938).png': 'Non-COVID',
#  'non_COVID (1051).png': 'Non-COVID',
#  'non_COVID (9821).png': 'Non-COVID',
#  'non_COVID (1391).png': 'Non-COVID',
#  'non_COVID (3148).png': 'Non-COVID',
#  'non_COVID (1235).png': 'Non-COVID',
#  'non_COVID (6209).png': 'Non-COVID',
#  'non_COVID (2474).png': 'Non-COVID',
#  'non_COVID (37).png': 'Non-COVID',
#  'non_COVID (2759).png': 'Non-COVID',
#  'non_COVID (1356).png': 'Non-COVID',
#  'non_COVID (375).png': 'Non-COVID',
#  'non_COVID (8603).png': 'Non-COVID',
#  'non_COVID (9752).png': 'Non-COVID',
#  'non_COVID (1412).png': 'Non-COVID',
#  'non_COVID (10559).png': 'Non-COVID',
#  'non_COVID (1860).png': 'Non-COVID',
#  'non_COVID (6573).png': 'Non-COVID',
#  'non_COVID (2843).png': 'Non-COVID',
#  'non_COVID (3219).png': 'Non-COVID',
#  'non_COVID (8496).png': 'Non-COVID',
#  'non_COVID (9114).png': 'Non-COVID',
#  'non_COVID (2226).png': 'Non-COVID',
#  'non_COVID (1827).png': 'Non-COVID',
#  'non_COVID (8503).png': 'Non-COVID',
#  'non_COVID (7525).png': 'Non-COVID',
#  'non_COVID (7870).png': 'Non-COVID',
#  'non_COVID (1256).png': 'Non-COVID',
#  'non_COVID (9677).png': 'Non-COVID',
#  'non_COVID (29).png': 'Non-COVID',
#  'non_COVID (7907).png': 'Non-COVID',
#  'non_COVID (7369).png': 'Non-COVID',
#  'non_COVID (1221).png': 'Non-COVID',
#  'non_COVID (7094).png': 'Non-COVID',
#  'non_COVID (2909).png': 'Non-COVID',
#  'non_COVID (1317).png': 'Non-COVID',
#  'non_COVID (9282).png': 'Non-COVID',
#  'non_COVID (3205).png': 'Non-COVID',
#  'non_COVID (6537).png': 'Non-COVID',
#  'non_COVID (7303).png': 'Non-COVID',
#  'non_COVID (2558).png': 'Non-COVID',
#  'non_COVID (10017).png': 'Non-COVID',
#  'non_COVID (1005).png': 'Non-COVID',
#  'non_COVID (10267).png': 'Non-COVID',
#  'non_COVID (2840).png': 'Non-COVID',
#  'non_COVID (6651).png': 'Non-COVID',
#  'non_COVID (278).png': 'Non-COVID',
#  'non_COVID (6945).png': 'Non-COVID',
#  'non_COVID (1008).png': 'Non-COVID',
#  'non_COVID (6504).png': 'Non-COVID',
#  'non_COVID (2260).png': 'Non-COVID',
#  'non_COVID (3206).png': 'Non-COVID',
#  'non_COVID (838).png': 'Non-COVID',
#  'non_COVID (7432).png': 'Non-COVID',
#  'non_COVID (2413).png': 'Non-COVID',
#  'non_COVID (8153).png': 'Non-COVID',
#  'non_COVID (3130).png': 'Non-COVID',
#  'non_COVID (1509).png': 'Non-COVID',
#  'non_COVID (10453).png': 'Non-COVID',
#  'non_COVID (6318).png': 'Non-COVID',
#  'non_COVID (1751).png': 'Non-COVID',
#  'non_COVID (9237).png': 'Non-COVID',
#  'non_COVID (8414).png': 'Non-COVID',
#  'non_COVID (7712).png': 'Non-COVID',
#  'non_COVID (9365).png': 'Non-COVID',
#  'non_COVID (2057).png': 'Non-COVID',
#  'non_COVID (1651).png': 'Non-COVID',
#  'non_COVID (6224).png': 'Non-COVID',
#  'non_COVID (578).png': 'Non-COVID',
#  'non_COVID (8519).png': 'Non-COVID',
#  'non_COVID (7275).png': 'Non-COVID',
#  'non_COVID (7709).png': 'Non-COVID',
#  'non_COVID (9217).png': 'Non-COVID',
#  'non_COVID (9670).png': 'Non-COVID',
#  'non_COVID (7702).png': 'Non-COVID',
#  'non_COVID (9037).png': 'Non-COVID',
#  'non_COVID (9242).png': 'Non-COVID',
#  'non_COVID (322).png': 'Non-COVID',
#  'non_COVID (7905).png': 'Non-COVID',
#  'non_COVID (7118).png': 'Non-COVID',
#  'non_COVID (467).png': 'Non-COVID',
#  'non_COVID (7675).png': 'Non-COVID',
#  'non_COVID (8395).png': 'Non-COVID',
#  'non_COVID (1997).png': 'Non-COVID',
#  'non_COVID (9832).png': 'Non-COVID',
#  'non_COVID (7886).png': 'Non-COVID',
#  'non_COVID (3213).png': 'Non-COVID',
#  'non_COVID (6300).png': 'Non-COVID',
#  'non_COVID (6552).png': 'Non-COVID',
#  'non_COVID (7500).png': 'Non-COVID',
#  'non_COVID (8874).png': 'Non-COVID',
#  'non_COVID (8525).png': 'Non-COVID',
#  'non_COVID (7504).png': 'Non-COVID',
#  'non_COVID (889).png': 'Non-COVID',
#  'non_COVID (8439).png': 'Non-COVID',
#  'non_COVID (9467).png': 'Non-COVID',
#  'non_COVID (8790).png': 'Non-COVID',
#  'non_COVID (8509).png': 'Non-COVID',
#  'non_COVID (121).png': 'Non-COVID',
#  'non_COVID (281).png': 'Non-COVID',
#  'non_COVID (10326).png': 'Non-COVID',
#  'non_COVID (10095).png': 'Non-COVID',
#  'non_COVID (7938).png': 'Non-COVID',
#  'non_COVID (6265).png': 'Non-COVID',
#  'non_COVID (10344).png': 'Non-COVID',
#  'non_COVID (1743).png': 'Non-COVID',
#  'non_COVID (10560).png': 'Non-COVID',
#  'non_COVID (9809).png': 'Non-COVID',
#  'non_COVID (8696).png': 'Non-COVID',
#  'non_COVID (7953).png': 'Non-COVID',
#  'non_COVID (6171).png': 'Non-COVID',
#  'non_COVID (7957).png': 'Non-COVID',
#  'non_COVID (6856).png': 'Non-COVID',
#  'non_COVID (1947).png': 'Non-COVID',
#  'non_COVID (10346).png': 'Non-COVID',
#  'non_COVID (304).png': 'Non-COVID',
#  'non_COVID (8624).png': 'Non-COVID',
#  'non_COVID (1073).png': 'Non-COVID',
#  'non_COVID (6909).png': 'Non-COVID',
#  'non_COVID (8768).png': 'Non-COVID',
#  'non_COVID (2555).png': 'Non-COVID',
#  'non_COVID (8628).png': 'Non-COVID',
#  'non_COVID (10558).png': 'Non-COVID',
#  'non_COVID (7483).png': 'Non-COVID',
#  'non_COVID (1342).png': 'Non-COVID',
#  'non_COVID (3064).png': 'Non-COVID',
#  'non_COVID (2567).png': 'Non-COVID',
#  'non_COVID (804).png': 'Non-COVID',
#  'non_COVID (8875).png': 'Non-COVID',
#  'non_COVID (837).png': 'Non-COVID',
#  'non_COVID (2163).png': 'Non-COVID',
#  'non_COVID (7597).png': 'Non-COVID',
#  'non_COVID (8291).png': 'Non-COVID',
#  'non_COVID (1318).png': 'Non-COVID',
#  'non_COVID (7857).png': 'Non-COVID',
#  'non_COVID (7630).png': 'Non-COVID',
#  'non_COVID (1496).png': 'Non-COVID',
#  'non_COVID (6320).png': 'Non-COVID',
#  'non_COVID (2514).png': 'Non-COVID',
#  'non_COVID (6816).png': 'Non-COVID',
#  'non_COVID (9954).png': 'Non-COVID',
#  'non_COVID (6550).png': 'Non-COVID',
#  'non_COVID (824).png': 'Non-COVID',
#  'non_COVID (9298).png': 'Non-COVID',
#  'non_COVID (9728).png': 'Non-COVID',
#  'non_COVID (9813).png': 'Non-COVID',
#  'non_COVID (6794).png': 'Non-COVID',
#  'Non_COVID (78).png': 'Non-COVID',
#  'non_COVID (9636).png': 'Non-COVID',
#  'non_COVID (7425).png': 'Non-COVID',
#  'non_COVID (41).png': 'Non-COVID',
#  'non_COVID (2826).png': 'Non-COVID',
#  'non_COVID (894).png': 'Non-COVID',
#  'non_COVID (9005).png': 'Non-COVID',
#  'non_COVID (471).png': 'Non-COVID',
#  'non_COVID (9835).png': 'Non-COVID',
#  'non_COVID (10465).png': 'Non-COVID',
#  'non_COVID (1132).png': 'Non-COVID',
#  'non_COVID (1425).png': 'Non-COVID',
#  'non_COVID (7789).png': 'Non-COVID',
#  'non_COVID (7251).png': 'Non-COVID',
#  'non_COVID (2048).png': 'Non-COVID',
#  'non_COVID (7557).png': 'Non-COVID',
#  'non_COVID (7170).png': 'Non-COVID',
#  'non_COVID (10053).png': 'Non-COVID',
#  'non_COVID (8076).png': 'Non-COVID',
#  'non_COVID (8661).png': 'Non-COVID',
#  'non_COVID (1199).png': 'Non-COVID',
#  'non_COVID (10592).png': 'Non-COVID',
#  'non_COVID (9361).png': 'Non-COVID',
#  'non_COVID (9844).png': 'Non-COVID',
#  'non_COVID (282).png': 'Non-COVID',
#  'non_COVID (6469).png': 'Non-COVID',
#  'non_COVID (10561).png': 'Non-COVID',
#  'non_COVID (10428).png': 'Non-COVID',
#  'non_COVID (302).png': 'Non-COVID',
#  'non_COVID (2650).png': 'Non-COVID',
#  'non_COVID (8259).png': 'Non-COVID',
#  'non_COVID (8641).png': 'Non-COVID',
#  'non_COVID (8854).png': 'Non-COVID',
#  'non_COVID (2651).png': 'Non-COVID',
#  'non_COVID (2113).png': 'Non-COVID',
#  'non_COVID (2754).png': 'Non-COVID',
#  'non_COVID (10146).png': 'Non-COVID',
#  'non_COVID (719).png': 'Non-COVID',
#  'non_COVID (7802).png': 'Non-COVID',
#  'non_COVID (8463).png': 'Non-COVID',
#  'non_COVID (10009).png': 'Non-COVID',
#  'non_COVID (9827).png': 'Non-COVID',
#  'non_COVID (9663).png': 'Non-COVID',
#  'non_COVID (480).png': 'Non-COVID',
#  'non_COVID (2499).png': 'Non-COVID',
#  'non_COVID (3090).png': 'Non-COVID',
#  'non_COVID (7311).png': 'Non-COVID',
#  'non_COVID (7859).png': 'Non-COVID',
#  'non_COVID (1160).png': 'Non-COVID',
#  'non_COVID (1685).png': 'Non-COVID',
#  'non_COVID (7078).png': 'Non-COVID',
#  'non_COVID (7293).png': 'Non-COVID',
#  'non_COVID (8334).png': 'Non-COVID',
#  'non_COVID (6158).png': 'Non-COVID',
#  'non_COVID (971).png': 'Non-COVID',
#  'non_COVID (10161).png': 'Non-COVID',
#  'non_COVID (9065).png': 'Non-COVID',
#  'non_COVID (6217).png': 'Non-COVID',
#  'non_COVID (1921).png': 'Non-COVID',
#  'non_COVID (6581).png': 'Non-COVID',
#  'non_COVID (8140).png': 'Non-COVID',
#  'non_COVID (8165).png': 'Non-COVID',
#  'non_COVID (8055).png': 'Non-COVID',
#  'non_COVID (7000).png': 'Non-COVID',
#  'non_COVID (539).png': 'Non-COVID',
#  'non_COVID (6539).png': 'Non-COVID',
#  'non_COVID (10114).png': 'Non-COVID',
#  'non_COVID (642).png': 'Non-COVID',
#  'non_COVID (274).png': 'Non-COVID',
#  'non_COVID (1362).png': 'Non-COVID',
#  'non_COVID (427).png': 'Non-COVID',
#  'non_COVID (1580).png': 'Non-COVID',
#  'non_COVID (8308).png': 'Non-COVID',
#  'non_COVID (8970).png': 'Non-COVID',
#  'non_COVID (138).png': 'Non-COVID',
#  'non_COVID (1124).png': 'Non-COVID',
#  'non_COVID (7112).png': 'Non-COVID',
#  'non_COVID (7046).png': 'Non-COVID',
#  'non_COVID (7617).png': 'Non-COVID',
#  'non_COVID (7946).png': 'Non-COVID',
#  'non_COVID (399).png': 'Non-COVID',
#  'non_COVID (2530).png': 'Non-COVID',
#  'non_COVID (6776).png': 'Non-COVID',
#  'non_COVID (8945).png': 'Non-COVID',
#  'non_COVID (8226).png': 'Non-COVID',
#  'non_COVID (7573).png': 'Non-COVID',
#  'non_COVID (6445).png': 'Non-COVID',
#  'non_COVID (6225).png': 'Non-COVID',
#  'non_COVID (2916).png': 'Non-COVID',
#  'non_COVID (10469).png': 'Non-COVID',
#  'non_COVID (6374).png': 'Non-COVID',
#  'non_COVID (9691).png': 'Non-COVID',
#  'non_COVID (7945).png': 'Non-COVID',
#  'non_COVID (1161).png': 'Non-COVID',
#  'non_COVID (7035).png': 'Non-COVID',
#  'non_COVID (130).png': 'Non-COVID',
#  'non_COVID (2933).png': 'Non-COVID',
#  'non_COVID (8528).png': 'Non-COVID',
#  'non_COVID (829).png': 'Non-COVID',
#  'non_COVID (739).png': 'Non-COVID',
#  'non_COVID (2158).png': 'Non-COVID',
#  'non_COVID (2976).png': 'Non-COVID',
#  'non_COVID (3198).png': 'Non-COVID',
#  'non_COVID (1773).png': 'Non-COVID',
#  'non_COVID (8487).png': 'Non-COVID',
#  'non_COVID (9411).png': 'Non-COVID',
#  'non_COVID (7931).png': 'Non-COVID',
#  'non_COVID (9251).png': 'Non-COVID',
#  'non_COVID (8780).png': 'Non-COVID',
#  'non_COVID (1988).png': 'Non-COVID',
#  'non_COVID (7974).png': 'Non-COVID',
#  'non_COVID (456).png': 'Non-COVID',
#  'non_COVID (6869).png': 'Non-COVID',
#  'non_COVID (8130).png': 'Non-COVID',
#  'non_COVID (6785).png': 'Non-COVID',
#  'non_COVID (6181).png': 'Non-COVID',
#  'non_COVID (122).png': 'Non-COVID',
#  'non_COVID (1400).png': 'Non-COVID',
#  'non_COVID (7199).png': 'Non-COVID',
#  'non_COVID (2798).png': 'Non-COVID',
#  'non_COVID (6538).png': 'Non-COVID',
#  'non_COVID (8609).png': 'Non-COVID',
#  'non_COVID (8010).png': 'Non-COVID',
#  'non_COVID (9566).png': 'Non-COVID',
#  'non_COVID (6157).png': 'Non-COVID',
#  'non_COVID (1223).png': 'Non-COVID',
#  'non_COVID (9207).png': 'Non-COVID',
#  'non_COVID (1849).png': 'Non-COVID',
#  'non_COVID (9334).png': 'Non-COVID',
#  'non_COVID (295).png': 'Non-COVID',
#  'non_COVID (2912).png': 'Non-COVID',
#  'non_COVID (7360).png': 'Non-COVID',
#  'non_COVID (1145).png': 'Non-COVID',
#  'non_COVID (10204).png': 'Non-COVID',
#  'non_COVID (2436).png': 'Non-COVID',
#  'non_COVID (10418).png': 'Non-COVID',
#  'non_COVID (9028).png': 'Non-COVID',
#  'non_COVID (8918).png': 'Non-COVID',
#  'non_COVID (7221).png': 'Non-COVID',
#  'non_COVID (6737).png': 'Non-COVID',
#  'non_COVID (1948).png': 'Non-COVID',
#  'non_COVID (109).png': 'Non-COVID',
#  'non_COVID (6160).png': 'Non-COVID',
#  'non_COVID (9426).png': 'Non-COVID',
#  'non_COVID (7427).png': 'Non-COVID',
#  'non_COVID (9637).png': 'Non-COVID',
#  'non_COVID (9397).png': 'Non-COVID',
#  'non_COVID (1234).png': 'Non-COVID',
#  'non_COVID (579).png': 'Non-COVID',
#  'non_COVID (8909).png': 'Non-COVID',
#  'non_COVID (6243).png': 'Non-COVID',
#  'non_COVID (6902).png': 'Non-COVID',
#  'non_COVID (6524).png': 'Non-COVID',
#  'non_COVID (10376).png': 'Non-COVID',
#  'non_COVID (10121).png': 'Non-COVID',
#  'non_COVID (8366).png': 'Non-COVID',
#  'non_COVID (8012).png': 'Non-COVID',
#  'non_COVID (10556).png': 'Non-COVID',
#  'non_COVID (9354).png': 'Non-COVID',
#  'non_COVID (9213).png': 'Non-COVID',
#  'non_COVID (1614).png': 'Non-COVID',
#  'non_COVID (3054).png': 'Non-COVID',
#  'non_COVID (2012).png': 'Non-COVID',
#  'non_COVID (651).png': 'Non-COVID',
#  'non_COVID (1302).png': 'Non-COVID',
#  'non_COVID (1109).png': 'Non-COVID',
#  'non_COVID (9040).png': 'Non-COVID',
#  'non_COVID (10125).png': 'Non-COVID',
#  'non_COVID (1149).png': 'Non-COVID',
#  'non_COVID (1513).png': 'Non-COVID',
#  'non_COVID (2330).png': 'Non-COVID',
#  'non_COVID (228).png': 'Non-COVID',
#  'non_COVID (10374).png': 'Non-COVID',
#  'non_COVID (2832).png': 'Non-COVID',
#  'non_COVID (9438).png': 'Non-COVID',
#  'non_COVID (9445).png': 'Non-COVID',
#  'non_COVID (2460).png': 'Non-COVID',
#  'non_COVID (3170).png': 'Non-COVID',
#  'non_COVID (7237).png': 'Non-COVID',
#  'non_COVID (2699).png': 'Non-COVID',
#  'non_COVID (8025).png': 'Non-COVID',
#  'non_COVID (671).png': 'Non-COVID',
#  'non_COVID (208).png': 'Non-COVID',
#  'non_COVID (986).png': 'Non-COVID',
#  'non_COVID (8662).png': 'Non-COVID',
#  'non_COVID (6655).png': 'Non-COVID',
#  'non_COVID (9742).png': 'Non-COVID',
#  'non_COVID (2001).png': 'Non-COVID',
#  'non_COVID (7374).png': 'Non-COVID',
#  'non_COVID (1388).png': 'Non-COVID',
#  'non_COVID (1409).png': 'Non-COVID',
#  'non_COVID (8296).png': 'Non-COVID',
#  'non_COVID (7533).png': 'Non-COVID',
#  'non_COVID (8976).png': 'Non-COVID',
#  'non_COVID (2787).png': 'Non-COVID',
#  'non_COVID (7835).png': 'Non-COVID',
#  'non_COVID (2161).png': 'Non-COVID',
#  'non_COVID (9224).png': 'Non-COVID',
#  'non_COVID (6614).png': 'Non-COVID',
#  'non_COVID (8691).png': 'Non-COVID',
#  'non_COVID (6362).png': 'Non-COVID',
#  'non_COVID (10484).png': 'Non-COVID',
#  'non_COVID (149).png': 'Non-COVID',
#  'non_COVID (8537).png': 'Non-COVID',
#  'non_COVID (2610).png': 'Non-COVID',
#  'non_COVID (881).png': 'Non-COVID',
#  'non_COVID (7599).png': 'Non-COVID',
#  'non_COVID (686).png': 'Non-COVID',
#  'non_COVID (3228).png': 'Non-COVID',
#  'non_COVID (9650).png': 'Non-COVID',
#  'non_COVID (7528).png': 'Non-COVID',
#  'non_COVID (10395).png': 'Non-COVID',
#  'non_COVID (8675).png': 'Non-COVID',
#  'non_COVID (9165).png': 'Non-COVID',
#  'non_COVID (7665).png': 'Non-COVID',
#  'non_COVID (624).png': 'Non-COVID',
#  'non_COVID (6513).png': 'Non-COVID',
#  'non_COVID (230).png': 'Non-COVID',
#  'non_COVID (132).png': 'Non-COVID',
#  'non_COVID (7869).png': 'Non-COVID',
#  'non_COVID (462).png': 'Non-COVID',
#  'non_COVID (2225).png': 'Non-COVID',
#  'non_COVID (8714).png': 'Non-COVID',
#  'non_COVID (10063).png': 'Non-COVID',
#  'non_COVID (9113).png': 'Non-COVID',
#  'non_COVID (3158).png': 'Non-COVID',
#  'non_COVID (6594).png': 'Non-COVID',
#  'non_COVID (9468).png': 'Non-COVID',
#  'non_COVID (8502).png': 'Non-COVID',
#  'non_COVID (2908).png': 'Non-COVID',
#  'non_COVID (10140).png': 'Non-COVID',
#  'non_COVID (8391).png': 'Non-COVID',
#  'non_COVID (10187).png': 'Non-COVID',
#  'non_COVID (3185).png': 'Non-COVID',
#  'non_COVID (7823).png': 'Non-COVID',
#  'non_COVID (8899).png': 'Non-COVID',
#  'non_COVID (7720).png': 'Non-COVID',
#  'non_COVID (7308).png': 'Non-COVID',
#  'non_COVID (8019).png': 'Non-COVID',
#  'non_COVID (753).png': 'Non-COVID',
#  'non_COVID (7080).png': 'Non-COVID',
#  'non_COVID (8196).png': 'Non-COVID',
#  'non_COVID (453).png': 'Non-COVID',
#  'non_COVID (10241).png': 'Non-COVID',
#  'non_COVID (7463).png': 'Non-COVID',
#  'non_COVID (19).png': 'Non-COVID',
#  'non_COVID (10279).png': 'Non-COVID',
#  'non_COVID (6213).png': 'Non-COVID',
#  'non_COVID (8866).png': 'Non-COVID',
#  'non_COVID (10289).png': 'Non-COVID',
#  'non_COVID (9957).png': 'Non-COVID',
#  'non_COVID (576).png': 'Non-COVID',
#  'non_COVID (10474).png': 'Non-COVID',
#  'non_COVID (10159).png': 'Non-COVID',
#  'non_COVID (8479).png': 'Non-COVID',
#  'non_COVID (6433).png': 'Non-COVID',
#  'non_COVID (1760).png': 'Non-COVID',
#  'non_COVID (2806).png': 'Non-COVID',
#  'non_COVID (2441).png': 'Non-COVID',
#  'non_COVID (731).png': 'Non-COVID',
#  'non_COVID (10445).png': 'Non-COVID',
#  'non_COVID (1101).png': 'Non-COVID',
#  'non_COVID (2569).png': 'Non-COVID',
#  'non_COVID (7448).png': 'Non-COVID',
#  'non_COVID (2322).png': 'Non-COVID',
#  'non_COVID (6575).png': 'Non-COVID',
#  'non_COVID (9025).png': 'Non-COVID',
#  'non_COVID (6355).png': 'Non-COVID',
#  'non_COVID (9357).png': 'Non-COVID',
#  'non_COVID (2812).png': 'Non-COVID',
#  'non_COVID (7600).png': 'Non-COVID',
#  'non_COVID (831).png': 'Non-COVID',
#  'non_COVID (10299).png': 'Non-COVID',
#  'non_COVID (1981).png': 'Non-COVID',
#  'non_COVID (648).png': 'Non-COVID',
#  'non_COVID (7759).png': 'Non-COVID',
#  'non_COVID (7383).png': 'Non-COVID',
#  'non_COVID (9859).png': 'Non-COVID',
#  'non_COVID (8697).png': 'Non-COVID',
#  'non_COVID (6700).png': 'Non-COVID',
#  'non_COVID (6389).png': 'Non-COVID',
#  'non_COVID (6599).png': 'Non-COVID',
#  'non_COVID (7800).png': 'Non-COVID',
#  'non_COVID (1061).png': 'Non-COVID',
#  'non_COVID (2686).png': 'Non-COVID',
#  'non_COVID (1229).png': 'Non-COVID',
#  'non_COVID (1262).png': 'Non-COVID',
#  'non_COVID (10419).png': 'Non-COVID',
#  'non_COVID (10226).png': 'Non-COVID',
#  'non_COVID (8284).png': 'Non-COVID',
#  'non_COVID (2833).png': 'Non-COVID',
#  'non_COVID (7595).png': 'Non-COVID',
#  'non_COVID (2430).png': 'Non-COVID',
#  'non_COVID (2664).png': 'Non-COVID',
#  'non_COVID (990).png': 'Non-COVID',
#  'non_COVID (8767).png': 'Non-COVID',
#  'non_COVID (7737).png': 'Non-COVID',
#  'non_COVID (9159).png': 'Non-COVID',
#  'non_COVID (6526).png': 'Non-COVID',
#  'non_COVID (3203).png': 'Non-COVID',
#  'non_COVID (235).png': 'Non-COVID',
#  'non_COVID (1960).png': 'Non-COVID',
#  'non_COVID (6921).png': 'Non-COVID',
#  'non_COVID (1666).png': 'Non-COVID',
#  'non_COVID (10551).png': 'Non-COVID',
#  'non_COVID (590).png': 'Non-COVID',
#  'non_COVID (7851).png': 'Non-COVID',
#  'non_COVID (472).png': 'Non-COVID',
#  'non_COVID (9599).png': 'Non-COVID',
#  'non_COVID (3240).png': 'Non-COVID',
#  'non_COVID (3153).png': 'Non-COVID',
#  'non_COVID (8963).png': 'Non-COVID',
#  'non_COVID (8452).png': 'Non-COVID',
#  'non_COVID (1220).png': 'Non-COVID',
#  'non_COVID (6703).png': 'Non-COVID',
#  'non_COVID (9964).png': 'Non-COVID',
#  'non_COVID (1565).png': 'Non-COVID',
#  'non_COVID (1958).png': 'Non-COVID',
#  'non_COVID (3016).png': 'Non-COVID',
#  'non_COVID (10562).png': 'Non-COVID',
#  'non_COVID (8637).png': 'Non-COVID',
#  'non_COVID (7181).png': 'Non-COVID',
#  'non_COVID (2464).png': 'Non-COVID',
#  'non_COVID (319).png': 'Non-COVID',
#  'non_COVID (1231).png': 'Non-COVID',
#  'non_COVID (6714).png': 'Non-COVID',
#  'non_COVID (514).png': 'Non-COVID',
#  'non_COVID (6303).png': 'Non-COVID',
#  'non_COVID (9430).png': 'Non-COVID',
#  'non_COVID (10420).png': 'Non-COVID',
#  'non_COVID (10402).png': 'Non-COVID',
#  'non_COVID (1464).png': 'Non-COVID',
#  'non_COVID (7574).png': 'Non-COVID',
#  'non_COVID (10598).png': 'Non-COVID',
#  'non_COVID (8951).png': 'Non-COVID',
#  'non_COVID (10280).png': 'Non-COVID',
#  'non_COVID (6744).png': 'Non-COVID',
#  'non_COVID (9509).png': 'Non-COVID',
#  'non_COVID (2987).png': 'Non-COVID',
#  'non_COVID (9912).png': 'Non-COVID',
#  'non_COVID (9162).png': 'Non-COVID',
#  'non_COVID (10037).png': 'Non-COVID',
#  'non_COVID (10003).png': 'Non-COVID',
#  'non_COVID (9557).png': 'Non-COVID',
#  'non_COVID (2205).png': 'Non-COVID',
#  'non_COVID (2067).png': 'Non-COVID',
#  'non_COVID (6920).png': 'Non-COVID',
#  'non_COVID (31).png': 'Non-COVID',
#  'non_COVID (8323).png': 'Non-COVID',
#  'non_COVID (6485).png': 'Non-COVID',
#  'non_COVID (9378).png': 'Non-COVID',
#  'non_COVID (8491).png': 'Non-COVID',
#  'non_COVID (9338).png': 'Non-COVID',
#  'non_COVID (8373).png': 'Non-COVID',
#  'non_COVID (8445).png': 'Non-COVID',
#  'non_COVID (1625).png': 'Non-COVID',
#  'non_COVID (6279).png': 'Non-COVID',
#  'non_COVID (405).png': 'Non-COVID',
#  'non_COVID (9593).png': 'Non-COVID',
#  'non_COVID (207).png': 'Non-COVID',
#  'non_COVID (10412).png': 'Non-COVID',
#  'non_COVID (9097).png': 'Non-COVID',
#  'non_COVID (8073).png': 'Non-COVID',
#  'non_COVID (924).png': 'Non-COVID',
#  'non_COVID (1054).png': 'Non-COVID',
#  'non_COVID (8928).png': 'Non-COVID',
#  'non_COVID (9154).png': 'Non-COVID',
#  'non_COVID (2152).png': 'Non-COVID',
#  'non_COVID (8131).png': 'Non-COVID',
#  'non_COVID (1896).png': 'Non-COVID',
#  'non_COVID (8041).png': 'Non-COVID',
#  'non_COVID (1838).png': 'Non-COVID',
#  'non_COVID (10251).png': 'Non-COVID',
#  'non_COVID (8024).png': 'Non-COVID',
#  'non_COVID (9623).png': 'Non-COVID',
#  'non_COVID (2374).png': 'Non-COVID',
#  'non_COVID (1534).png': 'Non-COVID',
#  'non_COVID (8008).png': 'Non-COVID',
#  'non_COVID (9574).png': 'Non-COVID',
#  'non_COVID (6790).png': 'Non-COVID',
#  'non_COVID (7441).png': 'Non-COVID',
#  'non_COVID (6534).png': 'Non-COVID',
#  'non_COVID (1505).png': 'Non-COVID',
#  'non_COVID (6239).png': 'Non-COVID',
#  'non_COVID (2579).png': 'Non-COVID',
#  'non_COVID (6882).png': 'Non-COVID',
#  'non_COVID (6601).png': 'Non-COVID',
#  'non_COVID (8215).png': 'Non-COVID',
#  'non_COVID (9799).png': 'Non-COVID',
#  'non_COVID (7242).png': 'Non-COVID',
#  'non_COVID (8174).png': 'Non-COVID',
#  'non_COVID (8903).png': 'Non-COVID',
#  'non_COVID (8017).png': 'Non-COVID',
#  'non_COVID (884).png': 'Non-COVID',
#  'non_COVID (6487).png': 'Non-COVID',
#  'non_COVID (2347).png': 'Non-COVID',
#  'non_COVID (8504).png': 'Non-COVID',
#  'non_COVID (9775).png': 'Non-COVID',
#  'non_COVID (9988).png': 'Non-COVID',
#  'non_COVID (7322).png': 'Non-COVID',
#  'non_COVID (7403).png': 'Non-COVID',
#  'non_COVID (9968).png': 'Non-COVID',
#  'non_COVID (7578).png': 'Non-COVID',
#  'Non_COVID (58).png': 'Non-COVID',
#  'non_COVID (9977).png': 'Non-COVID',
#  'non_COVID (2079).png': 'Non-COVID',
#  'non_COVID (930).png': 'Non-COVID',
#  'non_COVID (10483).png': 'Non-COVID',
#  'non_COVID (2824).png': 'Non-COVID',
#  'non_COVID (693).png': 'Non-COVID',
#  'non_COVID (2954).png': 'Non-COVID',
#  'non_COVID (10467).png': 'Non-COVID',
#  'non_COVID (10197).png': 'Non-COVID',
#  'non_COVID (10580).png': 'Non-COVID',
#  'Non_COVID (70).png': 'Non-COVID',
#  'non_COVID (727).png': 'Non-COVID',
#  'non_COVID (10231).png': 'Non-COVID',
#  'non_COVID (9990).png': 'Non-COVID',
#  'non_COVID (3200).png': 'Non-COVID',
#  'non_COVID (10195).png': 'Non-COVID',
#  'non_COVID (8442).png': 'Non-COVID',
#  'non_COVID (9711).png': 'Non-COVID',
#  'non_COVID (7865).png': 'Non-COVID',
#  'non_COVID (6821).png': 'Non-COVID',
#  'non_COVID (8723).png': 'Non-COVID',
#  'non_COVID (6174).png': 'Non-COVID',
#  'non_COVID (9470).png': 'Non-COVID',
#  'non_COVID (6846).png': 'Non-COVID',
#  'non_COVID (7449).png': 'Non-COVID',
#  'non_COVID (9606).png': 'Non-COVID',
#  'non_COVID (10179).png': 'Non-COVID',
#  'non_COVID (1090).png': 'Non-COVID',
#  'non_COVID (9910).png': 'Non-COVID',
#  'non_COVID (10103).png': 'Non-COVID',
#  'non_COVID (8241).png': 'Non-COVID',
#  'non_COVID (10403).png': 'Non-COVID',
#  'non_COVID (1649).png': 'Non-COVID',
#  'non_COVID (10552).png': 'Non-COVID',
#  'non_COVID (7365).png': 'Non-COVID',
#  'non_COVID (10084).png': 'Non-COVID',
#  'non_COVID (9263).png': 'Non-COVID',
#  'non_COVID (1370).png': 'Non-COVID',
#  'non_COVID (8957).png': 'Non-COVID',
#  'non_COVID (2942).png': 'Non-COVID',
#  'non_COVID (10293).png': 'Non-COVID',
#  'non_COVID (8515).png': 'Non-COVID',
#  'non_COVID (7674).png': 'Non-COVID',
#  'non_COVID (533).png': 'Non-COVID',
#  'non_COVID (6554).png': 'Non-COVID',
#  'non_COVID (7560).png': 'Non-COVID',
#  'non_COVID (10196).png': 'Non-COVID',
#  'non_COVID (8059).png': 'Non-COVID',
#  'non_COVID (2877).png': 'Non-COVID',
#  'non_COVID (459).png': 'Non-COVID',
#  'non_COVID (3160).png': 'Non-COVID',
#  'non_COVID (613).png': 'Non-COVID',
#  'non_COVID (7776).png': 'Non-COVID',
#  'non_COVID (1562).png': 'Non-COVID',
#  'non_COVID (10168).png': 'Non-COVID',
#  'non_COVID (7547).png': 'Non-COVID',
#  'non_COVID (2797).png': 'Non-COVID',
#  'non_COVID (640).png': 'Non-COVID',
#  'non_COVID (7660).png': 'Non-COVID',
#  'non_COVID (2401).png': 'Non-COVID',
#  'non_COVID (7652).png': 'Non-COVID',
#  'non_COVID (9362).png': 'Non-COVID',
#  'non_COVID (6838).png': 'Non-COVID',
#  'non_COVID (7941).png': 'Non-COVID',
#  'non_COVID (9123).png': 'Non-COVID',
#  'non_COVID (9533).png': 'Non-COVID',
#  'non_COVID (8776).png': 'Non-COVID',
#  'non_COVID (9707).png': 'Non-COVID',
#  'non_COVID (1816).png': 'Non-COVID',
#  'non_COVID (2172).png': 'Non-COVID',
#  'non_COVID (2380).png': 'Non-COVID',
#  'non_COVID (6724).png': 'Non-COVID',
#  'non_COVID (2002).png': 'Non-COVID',
#  'non_COVID (6571).png': 'Non-COVID',
#  'non_COVID (8796).png': 'Non-COVID',
#  'non_COVID (6726).png': 'Non-COVID',
#  'non_COVID (8908).png': 'Non-COVID',
#  'non_COVID (7055).png': 'Non-COVID',
#  'non_COVID (8091).png': 'Non-COVID',
#  'non_COVID (8532).png': 'Non-COVID',
#  'non_COVID (10543).png': 'Non-COVID',
#  'non_COVID (6704).png': 'Non-COVID',
#  'non_COVID (9266).png': 'Non-COVID',
#  'non_COVID (6903).png': 'Non-COVID',
#  'non_COVID (1275).png': 'Non-COVID',
#  'non_COVID (6878).png': 'Non-COVID',
#  'non_COVID (3002).png': 'Non-COVID',
#  'non_COVID (9228).png': 'Non-COVID',
#  'non_COVID (2542).png': 'Non-COVID',
#  'non_COVID (84).png': 'Non-COVID',
#  'non_COVID (7259).png': 'Non-COVID',
#  'non_COVID (10096).png': 'Non-COVID',
#  'non_COVID (10040).png': 'Non-COVID',
#  'non_COVID (3045).png': 'Non-COVID',
#  'non_COVID (862).png': 'Non-COVID',
#  'non_COVID (9548).png': 'Non-COVID',
#  'non_COVID (296).png': 'Non-COVID',
#  'non_COVID (383).png': 'Non-COVID',
#  'non_COVID (8699).png': 'Non-COVID',
#  'non_COVID (1942).png': 'Non-COVID',
#  'non_COVID (553).png': 'Non-COVID',
#  'non_COVID (7649).png': 'Non-COVID',
#  'non_COVID (7545).png': 'Non-COVID',
#  'non_COVID (1327).png': 'Non-COVID',
#  'non_COVID (1758).png': 'Non-COVID',
#  'non_COVID (8969).png': 'Non-COVID',
#  'non_COVID (9125).png': 'Non-COVID',
#  'non_COVID (1501).png': 'Non-COVID',
#  'non_COVID (9943).png': 'Non-COVID',
#  'non_COVID (6377).png': 'Non-COVID',
#  'non_COVID (8469).png': 'Non-COVID',
#  'non_COVID (1730).png': 'Non-COVID',
#  'non_COVID (7411).png': 'Non-COVID',
#  'non_COVID (7243).png': 'Non-COVID',
#  'non_COVID (1232).png': 'Non-COVID',
#  'non_COVID (7066).png': 'Non-COVID',
#  'non_COVID (6587).png': 'Non-COVID',
#  'non_COVID (6680).png': 'Non-COVID',
#  'non_COVID (6298).png': 'Non-COVID',
#  'non_COVID (8543).png': 'Non-COVID',
#  'non_COVID (7120).png': 'Non-COVID',
#  'Non_COVID (48).png': 'Non-COVID',
#  'non_COVID (2587).png': 'Non-COVID',
#  'non_COVID (6792).png': 'Non-COVID',
#  'non_COVID (2552).png': 'Non-COVID',
#  'non_COVID (1082).png': 'Non-COVID',
#  'non_COVID (1279).png': 'Non-COVID',
#  'non_COVID (9035).png': 'Non-COVID',
#  'non_COVID (7593).png': 'Non-COVID',
#  'non_COVID (2062).png': 'Non-COVID',
#  'non_COVID (7097).png': 'Non-COVID',
#  'non_COVID (10248).png': 'Non-COVID',
#  'non_COVID (7794).png': 'Non-COVID',
#  'non_COVID (1959).png': 'Non-COVID',
#  'non_COVID (8825).png': 'Non-COVID',
#  'non_COVID (9505).png': 'Non-COVID',
#  'non_COVID (6325).png': 'Non-COVID',
#  'non_COVID (1306).png': 'Non-COVID',
#  'non_COVID (8078).png': 'Non-COVID',
#  'non_COVID (7264).png': 'Non-COVID',
#  'non_COVID (6901).png': 'Non-COVID',
#  'non_COVID (7100).png': 'Non-COVID',
#  'non_COVID (258).png': 'Non-COVID',
#  'non_COVID (6544).png': 'Non-COVID',
#  'non_COVID (8658).png': 'Non-COVID',
#  'non_COVID (10595).png': 'Non-COVID',
#  'non_COVID (7568).png': 'Non-COVID',
#  'non_COVID (7053).png': 'Non-COVID',
#  'non_COVID (8742).png': 'Non-COVID',
#  'non_COVID (150).png': 'Non-COVID',
#  'non_COVID (8554).png': 'Non-COVID',
#  'non_COVID (8072).png': 'Non-COVID',
#  'non_COVID (6346).png': 'Non-COVID',
#  'non_COVID (9000).png': 'Non-COVID',
#  'non_COVID (10518).png': 'Non-COVID',
#  'non_COVID (2308).png': 'Non-COVID',
#  'non_COVID (9099).png': 'Non-COVID',
#  'non_COVID (8797).png': 'Non-COVID',
#  'non_COVID (7948).png': 'Non-COVID',
#  'non_COVID (9254).png': 'Non-COVID',
#  'non_COVID (10593).png': 'Non-COVID',
#  'non_COVID (1166).png': 'Non-COVID',
#  'non_COVID (8610).png': 'Non-COVID',
#  'non_COVID (1634).png': 'Non-COVID',
#  'non_COVID (6889).png': 'Non-COVID',
#  'non_COVID (10098).png': 'Non-COVID',
#  'non_COVID (8420).png': 'Non-COVID',
#  'non_COVID (987).png': 'Non-COVID',
#  'non_COVID (7150).png': 'Non-COVID',
#  'non_COVID (6642).png': 'Non-COVID',
#  'non_COVID (9143).png': 'Non-COVID',
#  'non_COVID (2389).png': 'Non-COVID',
#  'non_COVID (7182).png': 'Non-COVID',
#  'non_COVID (8258).png': 'Non-COVID',
#  'non_COVID (6799).png': 'Non-COVID',
#  'non_COVID (2021).png': 'Non-COVID',
#  'non_COVID (1755).png': 'Non-COVID',
#  'non_COVID (3186).png': 'Non-COVID',
#  'non_COVID (1890).png': 'Non-COVID',
#  'non_COVID (2792).png': 'Non-COVID',
#  'non_COVID (8574).png': 'Non-COVID',
#  'non_COVID (10199).png': 'Non-COVID',
#  'non_COVID (3086).png': 'Non-COVID',
#  'non_COVID (594).png': 'Non-COVID',
#  'non_COVID (8787).png': 'Non-COVID',
#  'non_COVID (937).png': 'Non-COVID',
#  'non_COVID (1060).png': 'Non-COVID',
#  'non_COVID (10358).png': 'Non-COVID',
#  'non_COVID (2489).png': 'Non-COVID',
#  'non_COVID (8123).png': 'Non-COVID',
#  'non_COVID (9331).png': 'Non-COVID',
#  'non_COVID (9056).png': 'Non-COVID',
#  'non_COVID (6453).png': 'Non-COVID',
#  'non_COVID (2088).png': 'Non-COVID',
#  'non_COVID (6691).png': 'Non-COVID',
#  'non_COVID (2505).png': 'Non-COVID',
#  'non_COVID (1335).png': 'Non-COVID',
#  'non_COVID (1156).png': 'Non-COVID',
#  'non_COVID (692).png': 'Non-COVID',
#  'non_COVID (9291).png': 'Non-COVID',
#  'non_COVID (8393).png': 'Non-COVID',
#  'non_COVID (10589).png': 'Non-COVID',
#  'non_COVID (9482).png': 'Non-COVID',
#  'non_COVID (8990).png': 'Non-COVID',
#  'non_COVID (8388).png': 'Non-COVID',
#  'non_COVID (7696).png': 'Non-COVID',
#  'non_COVID (8924).png': 'Non-COVID',
#  'non_COVID (1123).png': 'Non-COVID',
#  'non_COVID (2814).png': 'Non-COVID',
#  'non_COVID (7098).png': 'Non-COVID',
#  'non_COVID (3101).png': 'Non-COVID',
#  'non_COVID (535).png': 'Non-COVID',
#  'non_COVID (10004).png': 'Non-COVID',
#  'non_COVID (10566).png': 'Non-COVID',
#  'Non_COVID (52).png': 'Non-COVID',
#  'non_COVID (10407).png': 'Non-COVID',
#  'non_COVID (8906).png': 'Non-COVID',
#  'non_COVID (1378).png': 'Non-COVID',
#  'non_COVID (6725).png': 'Non-COVID',
#  'non_COVID (2126).png': 'Non-COVID',
#  'non_COVID (6569).png': 'Non-COVID',
#  'non_COVID (7034).png': 'Non-COVID',
#  'non_COVID (2229).png': 'Non-COVID',
#  'non_COVID (6906).png': 'Non-COVID',
#  'non_COVID (6858).png': 'Non-COVID',
#  'non_COVID (6472).png': 'Non-COVID',
#  'non_COVID (13).png': 'Non-COVID',
#  'non_COVID (8326).png': 'Non-COVID',
#  'non_COVID (2905).png': 'Non-COVID',
#  'non_COVID (882).png': 'Non-COVID',
#  'non_COVID (6231).png': 'Non-COVID',
#  'non_COVID (7406).png': 'Non-COVID',
#  'non_COVID (2771).png': 'Non-COVID',
#  'non_COVID (154).png': 'Non-COVID',
#  'non_COVID (6834).png': 'Non-COVID',
#  'non_COVID (2556).png': 'Non-COVID',
#  'non_COVID (6991).png': 'Non-COVID',
#  'non_COVID (960).png': 'Non-COVID',
#  'non_COVID (7727).png': 'Non-COVID',
#  'non_COVID (2625).png': 'Non-COVID',
#  'non_COVID (3075).png': 'Non-COVID',
#  'non_COVID (8593).png': 'Non-COVID',
#  'non_COVID (2805).png': 'Non-COVID',
#  'non_COVID (7741).png': 'Non-COVID',
#  'non_COVID (6964).png': 'Non-COVID',
#  'non_COVID (9196).png': 'Non-COVID',
#  'non_COVID (2452).png': 'Non-COVID',
#  'non_COVID (8037).png': 'Non-COVID',
#  'non_COVID (8335).png': 'Non-COVID',
#  'non_COVID (9104).png': 'Non-COVID',
#  'non_COVID (7768).png': 'Non-COVID',
#  'non_COVID (6371).png': 'Non-COVID',
#  'non_COVID (10000).png': 'Non-COVID',
#  'non_COVID (9090).png': 'Non-COVID',
#  'non_COVID (189).png': 'Non-COVID',
#  'non_COVID (9856).png': 'Non-COVID',
#  'non_COVID (3166).png': 'Non-COVID',
#  'non_COVID (627).png': 'Non-COVID',
#  'non_COVID (8013).png': 'Non-COVID',
#  'non_COVID (575).png': 'Non-COVID',
#  'non_COVID (9160).png': 'Non-COVID',
#  'non_COVID (9488).png': 'Non-COVID',
#  'non_COVID (2022).png': 'Non-COVID',
#  'non_COVID (801).png': 'Non-COVID',
#  'non_COVID (9172).png': 'Non-COVID',
#  'non_COVID (2045).png': 'Non-COVID',
#  'non_COVID (7002).png': 'Non-COVID',
#  'non_COVID (6414).png': 'Non-COVID',
#  'non_COVID (1732).png': 'Non-COVID',
#  'non_COVID (2958).png': 'Non-COVID',
#  'non_COVID (6166).png': 'Non-COVID',
#  'non_COVID (9628).png': 'Non-COVID',
#  'non_COVID (9766).png': 'Non-COVID',
#  'non_COVID (1339).png': 'Non-COVID',
#  'non_COVID (8683).png': 'Non-COVID',
#  'non_COVID (8953).png': 'Non-COVID',
#  'non_COVID (360).png': 'Non-COVID',
#  'non_COVID (6636).png': 'Non-COVID',
#  'non_COVID (6184).png': 'Non-COVID',
#  'non_COVID (9774).png': 'Non-COVID',
#  'non_COVID (10394).png': 'Non-COVID',
#  'non_COVID (7580).png': 'Non-COVID',
#  'non_COVID (7812).png': 'Non-COVID',
#  'non_COVID (1245).png': 'Non-COVID',
#  'non_COVID (3183).png': 'Non-COVID',
#  'non_COVID (1797).png': 'Non-COVID',
#  'non_COVID (592).png': 'Non-COVID',
#  'non_COVID (7494).png': 'Non-COVID',
#  'non_COVID (6795).png': 'Non-COVID',
#  'non_COVID (9672).png': 'Non-COVID',
#  'non_COVID (215).png': 'Non-COVID',
#  'non_COVID (9425).png': 'Non-COVID',
#  'non_COVID (9495).png': 'Non-COVID',
#  'non_COVID (10375).png': 'Non-COVID',
#  'non_COVID (9923).png': 'Non-COVID',
#  'non_COVID (9587).png': 'Non-COVID',
#  'non_COVID (8999).png': 'Non-COVID',
#  'non_COVID (2565).png': 'Non-COVID',
#  'non_COVID (1242).png': 'Non-COVID',
#  'non_COVID (8447).png': 'Non-COVID',
#  'non_COVID (10493).png': 'Non-COVID',
#  'non_COVID (1813).png': 'Non-COVID',
#  'non_COVID (1696).png': 'Non-COVID',
#  'non_COVID (10357).png': 'Non-COVID',
#  'non_COVID (805).png': 'Non-COVID',
#  'non_COVID (10404).png': 'Non-COVID',
#  'non_COVID (7618).png': 'Non-COVID',
#  'non_COVID (1909).png': 'Non-COVID',
#  'non_COVID (7643).png': 'Non-COVID',
#  'non_COVID (8634).png': 'Non-COVID',
#  'non_COVID (390).png': 'Non-COVID',
#  'non_COVID (841).png': 'Non-COVID',
#  'non_COVID (7663).png': 'Non-COVID',
#  'non_COVID (10072).png': 'Non-COVID',
#  'non_COVID (2780).png': 'Non-COVID',
#  'non_COVID (6578).png': 'Non-COVID',
#  'non_COVID (9608).png': 'Non-COVID',
#  'non_COVID (1056).png': 'Non-COVID',
#  'non_COVID (2228).png': 'Non-COVID',
#  'non_COVID (6446).png': 'Non-COVID',
#  'non_COVID (9442).png': 'Non-COVID',
#  'non_COVID (2680).png': 'Non-COVID',
#  'non_COVID (10361).png': 'Non-COVID',
#  'non_COVID (9087).png': 'Non-COVID',
#  'non_COVID (8917).png': 'Non-COVID',
#  'non_COVID (7498).png': 'Non-COVID',
#  'non_COVID (10410).png': 'Non-COVID',
#  'non_COVID (6498).png': 'Non-COVID',
#  'non_COVID (1238).png': 'Non-COVID',
#  'non_COVID (637).png': 'Non-COVID',
#  'non_COVID (8216).png': 'Non-COVID',
#  'non_COVID (1274).png': 'Non-COVID',
#  'non_COVID (156).png': 'Non-COVID',
#  'non_COVID (999).png': 'Non-COVID',
#  'non_COVID (921).png': 'Non-COVID',
#  'non_COVID (1433).png': 'Non-COVID',
#  'non_COVID (3118).png': 'Non-COVID',
#  'non_COVID (6958).png': 'Non-COVID',
#  'non_COVID (6528).png': 'Non-COVID',
#  'non_COVID (6654).png': 'Non-COVID',
#  'non_COVID (8011).png': 'Non-COVID',
#  'non_COVID (10389).png': 'Non-COVID',
#  'non_COVID (2842).png': 'Non-COVID',
#  'non_COVID (10494).png': 'Non-COVID',
#  'non_COVID (3187).png': 'Non-COVID',
#  'non_COVID (3117).png': 'Non-COVID',
#  'non_COVID (626).png': 'Non-COVID',
#  'non_COVID (9188).png': 'Non-COVID',
#  'non_COVID (9808).png': 'Non-COVID',
#  'non_COVID (9278).png': 'Non-COVID',
#  'non_COVID (7924).png': 'Non-COVID',
#  ...}

# %%
train_df1 = pd.DataFrame(dict_img.items(), columns=['file_names', 'lables'])

train_df1
# Out:
#                  file_names     lables
# 0      non_COVID (2869).png  Non-COVID
# 1      non_COVID (8492).png  Non-COVID
# 2      non_COVID (8910).png  Non-COVID
# 3      non_COVID (2237).png  Non-COVID
# 4      non_COVID (1866).png  Non-COVID
# ...                     ...        ...
# 21710    Normal (10669).png     Normal
# 21711     Normal (5903).png     Normal
# 21712     Normal (4890).png     Normal
# 21713     Normal (5207).png     Normal
# 21714     Normal (4097).png     Normal
#
# [21715 rows x 2 columns]

# %%
# tao danh sach chua file_name image va label
def create_list(path_folder):
    label = os.listdir(path_folder)
    img_label_list =[]
    for lbl in label:
        list_file_name = os.listdir(path_folder +lbl +'/images')
        img_label_list+=[(file_name, lbl) for file_name in list_file_name] # https://www.stackvidhya.com/concatenate-lists-in-python/#:~:text=You%20can%20concatenate%20multiple%20lists,single%20list%20in%20one%20shot
    return img_label_list

# %%
train_list = create_list(lung_data+'Train/')
val_list = create_list(lung_data+'Val/')
test_list = create_list(lung_data+'Test/')

# %%
#tao table (dataframe) để lưu img_label_list
train_df = pd.DataFrame(train_list, columns = ['file_name', 'label'])
val_df = pd.DataFrame(val_list, columns = ['file_name', 'label'])
test_df = pd.DataFrame(test_list, columns = ['file_name', 'label'])

# %%
# ghi file csv 
train_df.to_csv(lung_data+'train.csv',header=True, index = False) #ghi file csv, header = column name, if index = True then add 1 columns
val_df.to_csv(lung_data+'val.csv',header=True, index = False)
test_df.to_csv(lung_data+'test.csv',header=True, index = False)

# %%
# doc file csv
train_csv = pd.read_csv(lung_data+'train.csv') # doc file csv
val_csv = pd.read_csv(lung_data+'val.csv') # doc file csv
test_csv = pd.read_csv(lung_data+'test.csv') # doc file csv

# %%
# ve phan bo data tren train, val, test
# https://stackabuse.com/matplotlib-bar-plot-tutorial-and-examples/
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm

len_train , len_val, len_test = len(train_csv), len(val_csv), len(test_csv)

# print(len_train , len_val, len_test)
x = ['Train', 'Val', 'Test']
y = [len_train, len_val, len_test]
plt.bar(x, y, color = ['b', 'g', 'r'], width=0.5)
plt.show()

len(train_csv), len(val_csv), len(test_csv)
# Out:
# (21715, 5417, 6788)

# %%
# dem so luong cac class trong train_csv
# https://re-thought.com/pandas-value_counts/#:~:text=The%20value_counts%20%28%29%20function%20is%20used%20to%20get,the%20first%20element%20is%20the%20most%20frequently-occurring%20element.

lst_train = list(train_csv['label'].value_counts())
lst_val = list(val_csv['label'].value_counts())
lst_test = list(test_csv['label'].value_counts())

# %%
test_csv['label'].value_counts()
# Out:
# COVID-19     2395
# Non-COVID    2253
# Normal       2140
# Name: label, dtype: int64

# %%
visualize_distribute_dataset(lst_train, lst_val, lst_test)

# %%
train_dataset = ImageDataset(train_csv, lung_data + 'Train', augs)
train_dataloader = DataLoader(train_dataset, batch_size = 8, shuffle=True)
img, mask, label, file_name = next(iter(train_dataloader))
img, mask = img_de_normalize(img, mask)
# imshow_img_mask(img,mask,label)
imshow_img_mask(img, mask, file_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2594/3908747893.py in <module>
#       1 train_dataset = ImageDataset(train_csv, lung_data + 'Train', augs)
#       2 train_dataloader = DataLoader(train_dataset, batch_size = 8, shuffle=True)
# ----> 3 img, mask, label, file_name = next(iter(train_dataloader))
#       4 img, mask = img_de_normalize(img, mask)
#       5 # imshow_img_mask(img,mask,label)
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     650                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     651                 self._reset()  # type: ignore[call-arg]
# --> 652             data = self._next_data()
#     653             self._num_yielded += 1
#     654             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     690     def _next_data(self):
#     691         index = self._next_index()  # may raise StopIteration
# --> 692         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     693         if self._pin_memory:
#     694             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /mnt/DATA/covid19_resnet152_python-main/archive_14gb/mainscript/segment/script/custom_dataset.py in __getitem__(self, index)
#      35         image = np.expand_dims(image,0).transpose(1,2,0)#### (256, 256, 1)
#      36         if self.transform != None:
# ---> 37             aug = self.transform(image = image, mask = mask)
#      38             image=aug['image']
#      39             mask = aug['mask']
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/albumentations/core/composition.py in __call__(self, force_apply, *args, **data)
#     203
#     204         for idx, t in enumerate(transforms):
# --> 205             data = t(force_apply=force_apply, **data)
#     206
#     207             if check_each_transform:
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/albumentations/core/transforms_interface.py in __call__(self, force_apply, *args, **kwargs)
#      96                     )
#      97                 kwargs[self.save_key][id(self)] = deepcopy(params)
# ---> 98             return self.apply_with_params(params, **kwargs)
#      99
#     100         return kwargs
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/albumentations/core/transforms_interface.py in apply_with_params(self, params, **kwargs)
#     109                 target_function = self._get_target_function(key)
#     110                 target_dependencies = {k: kwargs[k] for k in self.target_dependence.get(key, [])}
# --> 111                 res[key] = target_function(arg, **dict(params, **target_dependencies))
#     112             else:
#     113                 res[key] = None
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/albumentations/augmentations/transforms.py in apply(self, image, **params)
#     678
#     679     def apply(self, image, **params):
# --> 680         return F.normalize(image, self.mean, self.std, self.max_pixel_value)
#     681
#     682     def get_transform_init_args_names(self):
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/albumentations/augmentations/functional.py in normalize(img, mean, std, max_pixel_value)
#     255
#     256     img = img.astype(np.float32)
# --> 257     img -= mean
#     258     img *= denominator
#     259     return img
#
# ValueError: non-broadcastable output operand with shape (256,256,1) doesn't match the broadcast shape (256,256,3)

# %%
transfms_M_STD = A.Compose([
    A.Resize(256,256),
    A.Normalize(mean = [0.], std =[1.]), # scale pixel values from [0,255] to [0,1]
    ToTensorV2() 
])

train_dt = ImageDataset(train_csv, lung_data+ 'Train', transfms_M_STD)
train_loader = DataLoader(train_dt, batch_size=32, shuffle = False)
img, _, _, _  = next(iter(train_loader))
print(img.size())
# Out:
# torch.Size([32, 1, 256, 256])

# %%
def compute_mean_std(dataloader):
    mean1 = 0.
    std1 = 0.
    nb_samples = 0.
    for data, _, _, _ in tqdm(dataloader):
        batch_samples = data.size(0)

        # Rearrange data to be the shape of [B, C, W * H]
        data = data.view(batch_samples, data.size(1), -1) # torch.Size([32, 1, 65536])
        
        # Compute mean and std here
        mean1 += data.mean(2).sum(0) #tinh mean theo width*height va lay tong theo batch_size
        # print(data.mean(2).size())
        std1 += data.std(2).sum(0)

        # Update total number of images
        nb_samples += batch_samples
    mean1 /= nb_samples
    std1 /= nb_samples

    return mean1, std1

mean, std = compute_mean_std(train_loader)
print(mean, std)
# Out:
# 100%|██████████| 679/679 [00:31<00:00, 21.64it/s]
# tensor([0.5128]) tensor([0.2220])

# %%
# import os
# import torch

# from tqdm.notebook import tqdm
# from time import time
 
# N_CHANNELS = 1
 
# train_dataset = ImageDataset(train_csv, lung_data + 'Train', augs)
# train_dataloader = DataLoader(train_dataset, batch_size = 8, shuffle=True)
 
# before = time()
# mean = torch.zeros(1)
# std = torch.zeros(1)
# print('==> Computing mean and std..')
# for inputs, _labels, _, _ in tqdm(train_dataloader):
#     for i in range(N_CHANNELS):
#         mean[i] += inputs[:,i,:,:].mean()
#         std[i] += inputs[:,i,:,:].std()
# mean.div_(len(train_dataset))
# std.div_(len(train_dataset))
# print(mean, std)
 
# print("time elapsed: ", time()-before)
